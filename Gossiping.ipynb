# %%
import pandas as pd
index0 = pd.read_csv("/Users/guanlizhe/Desktop/code/python/web_crawer/ptt_/ptt_data/Gossiping/index0-1.csv", index_col=[0],low_memory=False)
index1 = pd.read_csv("/Users/guanlizhe/Desktop/code/python/web_crawer/ptt_/ptt_data/Gossiping/index1-2.csv", index_col=[0],low_memory=False)
index2 = pd.read_csv("/Users/guanlizhe/Desktop/code/python/web_crawer/ptt_/ptt_data/Gossiping/index2-3.csv", index_col=[0],low_memory=False)
index3 = pd.read_csv("/Users/guanlizhe/Desktop/code/python/web_crawer/ptt_/ptt_data/Gossiping/index3-4.csv", index_col=[0],low_memory=False)
index4 = pd.read_csv("/Users/guanlizhe/Desktop/code/python/web_crawer/ptt_/ptt_data/Gossiping/index4-5.csv", index_col=[0],low_memory=False)
index5 = pd.read_csv("/Users/guanlizhe/Desktop/code/python/web_crawer/ptt_/ptt_data/Gossiping/index5-6.csv", index_col=[0],low_memory=False)
index6 = pd.read_csv("/Users/guanlizhe/Desktop/code/python/web_crawer/ptt_/ptt_data/Gossiping/index6-7.csv", index_col=[0],low_memory=False)
index7 = pd.read_csv("/Users/guanlizhe/Desktop/code/python/web_crawer/ptt_/ptt_data/Gossiping/index7-8.csv", index_col=[0],low_memory=False)
index8 = pd.read_csv("/Users/guanlizhe/Desktop/code/python/web_crawer/ptt_/ptt_data/Gossiping/index8-9.csv", index_col=[0],low_memory=False)
index9 = pd.read_csv("/Users/guanlizhe/Desktop/code/python/web_crawer/ptt_/ptt_data/Gossiping/index9-10.csv", index_col=[0],low_memory=False)
index10 = pd.read_csv("/Users/guanlizhe/Desktop/code/python/web_crawer/ptt_/ptt_data/Gossiping/index10-11.csv", index_col=[0],low_memory=False)


index11 = pd.read_csv("/Users/guanlizhe/Desktop/code/python/web_crawer/ptt_/ptt_data/Gossiping/index11-12.csv", index_col=[0],low_memory=False)
index12 = pd.read_csv("/Users/guanlizhe/Desktop/code/python/web_crawer/ptt_/ptt_data/Gossiping/index12-13.csv", index_col=[0],low_memory=False)
index13 = pd.read_csv("/Users/guanlizhe/Desktop/code/python/web_crawer/ptt_/ptt_data/Gossiping/index13-14.csv", index_col=[0],low_memory=False)
index14 = pd.read_csv("/Users/guanlizhe/Desktop/code/python/web_crawer/ptt_/ptt_data/Gossiping/index14-15.csv", index_col=[0],low_memory=False)
index15 = pd.read_csv("/Users/guanlizhe/Desktop/code/python/web_crawer/ptt_/ptt_data/Gossiping/index15-16.csv", index_col=[0],low_memory=False)
index16 = pd.read_csv("/Users/guanlizhe/Desktop/code/python/web_crawer/ptt_/ptt_data/Gossiping/index16-17.csv", index_col=[0],low_memory=False)
index17 = pd.read_csv("/Users/guanlizhe/Desktop/code/python/web_crawer/ptt_/ptt_data/Gossiping/index17-18.csv", index_col=[0],low_memory=False)
index18 = pd.read_csv("/Users/guanlizhe/Desktop/code/python/web_crawer/ptt_/ptt_data/Gossiping/index18-19.csv", index_col=[0],low_memory=False)
index19 = pd.read_csv("/Users/guanlizhe/Desktop/code/python/web_crawer/ptt_/ptt_data/Gossiping/index19-20.csv", index_col=[0],low_memory=False)
index20 = pd.read_csv("/Users/guanlizhe/Desktop/code/python/web_crawer/ptt_/ptt_data/Gossiping/index20-21.csv", index_col=[0],low_memory=False)


index21 = pd.read_csv("/Users/guanlizhe/Desktop/code/python/web_crawer/ptt_/ptt_data/Gossiping/index21-22.csv", index_col=[0],low_memory=False)
index22 = pd.read_csv("/Users/guanlizhe/Desktop/code/python/web_crawer/ptt_/ptt_data/Gossiping/index22-23.csv", index_col=[0],low_memory=False)
index23 = pd.read_csv("/Users/guanlizhe/Desktop/code/python/web_crawer/ptt_/ptt_data/Gossiping/index23-24.csv", index_col=[0],low_memory=False)
index24 = pd.read_csv("/Users/guanlizhe/Desktop/code/python/web_crawer/ptt_/ptt_data/Gossiping/index24-25.csv", index_col=[0],low_memory=False)
index25 = pd.read_csv("/Users/guanlizhe/Desktop/code/python/web_crawer/ptt_/ptt_data/Gossiping/index25-26.csv", index_col=[0],low_memory=False)
index26 = pd.read_csv("/Users/guanlizhe/Desktop/code/python/web_crawer/ptt_/ptt_data/Gossiping/index26-27.csv", index_col=[0],low_memory=False)
index27 = pd.read_csv("/Users/guanlizhe/Desktop/code/python/web_crawer/ptt_/ptt_data/Gossiping/index27-28.csv", index_col=[0],low_memory=False)
index28 = pd.read_csv("/Users/guanlizhe/Desktop/code/python/web_crawer/ptt_/ptt_data/Gossiping/index28-29.csv", index_col=[0],low_memory=False)
index29 = pd.read_csv("/Users/guanlizhe/Desktop/code/python/web_crawer/ptt_/ptt_data/Gossiping/index29-30.csv", index_col=[0],low_memory=False)
index30 = pd.read_csv("/Users/guanlizhe/Desktop/code/python/web_crawer/ptt_/ptt_data/Gossiping/index30-31.csv", index_col=[0],low_memory=False)


index31 = pd.read_csv("/Users/guanlizhe/Desktop/code/python/web_crawer/ptt_/ptt_data/Gossiping/index31-32.csv", index_col=[0],low_memory=False)
index32 = pd.read_csv("/Users/guanlizhe/Desktop/code/python/web_crawer/ptt_/ptt_data/Gossiping/index32-33.csv", index_col=[0],low_memory=False)
index33 = pd.read_csv("/Users/guanlizhe/Desktop/code/python/web_crawer/ptt_/ptt_data/Gossiping/index33-34.csv", index_col=[0],low_memory=False)
index34 = pd.read_csv("/Users/guanlizhe/Desktop/code/python/web_crawer/ptt_/ptt_data/Gossiping/index34-35.csv", index_col=[0],low_memory=False)
index35 = pd.read_csv("/Users/guanlizhe/Desktop/code/python/web_crawer/ptt_/ptt_data/Gossiping/index35-36.csv", index_col=[0],low_memory=False)
index36 = pd.read_csv("/Users/guanlizhe/Desktop/code/python/web_crawer/ptt_/ptt_data/Gossiping/index36-37.csv", index_col=[0],low_memory=False)
index37 = pd.read_csv("/Users/guanlizhe/Desktop/code/python/web_crawer/ptt_/ptt_data/Gossiping/index37-38.csv", index_col=[0],low_memory=False)
index38 = pd.read_csv("/Users/guanlizhe/Desktop/code/python/web_crawer/ptt_/ptt_data/Gossiping/index38-39.csv", index_col=[0],low_memory=False)

# %%
df = pd.concat([index0,index1,index2,index3,index4,index5,index6,index7,index8,index9,index10,index11,index12,index13,index14,index15,index16,index17,index18,index19,index20,index21,index22,index23,index24,index25,index26,index27,index28,index29,index30,index31,index32,index33,index34,index35,index36,index37,index38], ignore_index=True)
df
# Out:
#                 userID tag            content   date   year
# 0              bullets   →          :被M了，恭喜!!  06/20   2005
# 1                zebec   推     :哇～這樣就可以拿一千，真好  06/20   2005
# 2         survivalteru   噓                  :  09/21   2005
# 3           chivalry10   噓               :沒原因  03/12   2005
# 4                usera   噓                  :  12/27   2005
# ...                ...  ..                ...    ...    ...
# 37469455        GTRNO1   →                 好喝  12/01   2022
# 37469456        cccict   →     味噌跟豆瓣醬是不是同一種東西  12/01   2022
# 37469457         Aukid   推     google就有的答案還來問  12/01   2022
# 37469458         ncaaa   推          差在味增湯比較好喝  12/01   2022
