# %%
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
# df = pd.read_csv("/Users/guanlizhe/Desktop/nccu/NLP/body_shaming/main_code/all_label.csv", index_col=[0],low_memory=False)
df_rs = pd.read_csv("/Users/guanlizhe/Desktop/nccu/NLP/body_shaming/main_code/random_df.csv", index_col=[0],low_memory=False)

# %%
# df[['tag_num', 'content', 'similar_animal', 'similar_object', 'body', 'direct_adj', 'verb', 'slur', 'sex', 'lgbt', 'status', 'label_ver2']]

# %% [markdown]
# ## 把資料分成8:2的訓練集和測試集

# %%
from sklearn.model_selection import train_test_split

all_features = df_rs[['tag_num', 'gender_female', 'gender_lgbt', 'pubertal_development', 'sexual_harrasment', 'appearance_object', 'appearance_animal', 'mother', 'attitude','shame']]
all_labels = df_rs['label_ver2']

# all_features = df[['tag_num', 'gender_female', 'gender_lgbt', 'pubertal_development', 'sexual_harrasment', 'appearance_object', 'appearance_animal', 'mother', 'attitude','shame']]
# all_labels = df['label_ver2']

feat_train, feat_test, label_train, label_test = train_test_split(all_features, all_labels, train_size=0.8, random_state=50)

# feat_train, feat_test, label_train, label_test = train_test_split(all_features, all_labels, train_size=0.8)

# %%
feat_train
# Out:
#        tag_num  gender_female  gender_lgbt  pubertal_development  \
# 1515         0              0            0                     0
# 1858         2              0            0                     0
# 10765        2              0            0                     0
# 12723        2              0            0                     0
# 227          2              0            0                     0
# ...        ...            ...          ...                   ...
# 10206        2              0            0                     0
# 6253         0              0            0                     0
# 10123        0              0            0                     0
# 5600         0              0            0                     0
# 14000        1              0            0                     0
#
#        sexual_harrasment  appearance_object  appearance_animal  mother  \
# 1515                   0                  0                  0       0
# 1858                   0                  0                  0       0
# 10765                  0                  0                  0       0
# 12723                  0                  0                  0       0
# 227                    0                  0                  1       0
# ...                  ...                ...                ...     ...
# 10206                  0                  0                  1       0
# 6253                   0                  0                  0       0
# 10123                  0                  0                  0       0
# 5600                   0                  0                  0       0
# 14000                  0                  0                  1       0
#
#        attitude  shame
# 1515          0      0
# 1858          1      0
# 10765         0      0
# 12723         1      0
# 227           0      0
# ...         ...    ...
# 10206         0      0
# 6253          0      0
# 10123         0      0
# 5600          0      0
# 14000         0      0
#
# [11560 rows x 10 columns]

# %% [markdown]
# ## naive bayes model

# %%
from sklearn.naive_bayes import MultinomialNB
nb_model = MultinomialNB()
nb_model.fit(feat_train, label_train)
# Out:
# MultinomialNB()

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import classification_report

predicted_nb = nb_model.predict(feat_test)
bayes_accuracy = accuracy_score(label_test, predicted_nb)
bayes_fscore = f1_score(label_test, predicted_nb, average='micro') 

print(bayes_accuracy)
print(bayes_fscore)
# Out:
# 0.7678200692041522
# 0.7678200692041522

# %%
import eli5
from eli5.sklearn import PermutationImportance

perm = PermutationImportance(nb_model, random_state=1).fit(feat_test, label_test)
eli5.show_weights(perm, feature_names = feat_test.columns.tolist())
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1621
#
#                     &plusmn; 0.0092
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 attitude
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 87.83%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0797
#
#                     &plusmn; 0.0096
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 appearance_animal
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 95.08%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0219
#
#                     &plusmn; 0.0066
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 pubertal_development
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.13%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0155
#
#                     &plusmn; 0.0034
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 shame
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.13%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0101
#
#                     &plusmn; 0.0046
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 tag_num
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.79%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0070
#
#                     &plusmn; 0.0025
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 appearance_object
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.43%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0043
#
#                     &plusmn; 0.0009
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 sexual_harrasment
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.90%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0026
#
#                     &plusmn; 0.0009
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 gender_lgbt
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.26%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0015
#
#                     &plusmn; 0.0026
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 mother
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 100.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0
#
#                     &plusmn; 0.0000
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 gender_female
#             </td>
#         </tr>
#
#
#     </tbody>
# </table>

# %%
report_nb = classification_report(label_test, predicted_nb)
print(report_nb)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.87      0.83      1592
#            1       0.73      0.73      0.73      1105
#            2       0.48      0.11      0.18       180
#            3       0.00      0.00      0.00        13
#
#     accuracy                           0.77      2890
#    macro avg       0.50      0.43      0.44      2890
# weighted avg       0.75      0.77      0.75      2890

# %% [markdown]
# ## Decision Tree

# %%
from sklearn import tree

dt_model = tree.DecisionTreeClassifier()
dt_model.fit(feat_train, label_train)
# Out:
# DecisionTreeClassifier()

# %%
predicted_dt = dt_model.predict(feat_test)
dt_accuracy = accuracy_score(label_test, predicted_dt)
dt_fscore = f1_score(label_test, predicted_dt, average='micro') 

print(dt_accuracy)
print(dt_fscore)
# Out:
# 0.8636678200692042
# 0.8636678200692043

# %%
import eli5
from eli5.sklearn import PermutationImportance

perm = PermutationImportance(dt_model, random_state=1).fit(feat_test, label_test)
eli5.show_weights(perm, feature_names = feat_test.columns.tolist())
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.3019
#
#                     &plusmn; 0.0057
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 attitude
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 89.10%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1269
#
#                     &plusmn; 0.0076
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 appearance_animal
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.39%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0165
#
#                     &plusmn; 0.0043
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 appearance_object
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.60%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0146
#
#                     &plusmn; 0.0036
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 pubertal_development
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.35%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0023
#
#                     &plusmn; 0.0030
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 shame
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.42%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0019
#
#                     &plusmn; 0.0014
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 mother
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.48%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0017
#
#                     &plusmn; 0.0007
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 sexual_harrasment
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.85%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0003
#
#                     &plusmn; 0.0025
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 tag_num
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.94%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0001
#
#                     &plusmn; 0.0003
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 gender_lgbt
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 100.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0
#
#                     &plusmn; 0.0000
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 gender_female
#             </td>
#         </tr>
#
#
#     </tbody>
# </table>

# %%
report_dt = classification_report(label_test, predicted_dt)
print(report_dt)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.85      0.90      1592
#            1       0.78      0.98      0.87      1105
#            2       0.69      0.32      0.43       180
#            3       0.00      0.00      0.00        13
#
#     accuracy                           0.86      2890
#    macro avg       0.61      0.54      0.55      2890
# weighted avg       0.87      0.86      0.86      2890

# %%
from IPython.display import Image
import pydot
tree.export_graphviz(dt_model, out_file='tree.dot', feature_names=list(all_features))
(graph,) = pydot.graph_from_dot_file('tree.dot')
graph.write_png('tree.png')
Image(graph.create_png())

# %% [markdown]
# ## SVM

# %%
from sklearn import svm

svm_model = svm.SVC(kernel='poly', C=1)
svm_model.fit(feat_train, label_train)
# Out:
# SVC(C=1, kernel='poly')

# %%
predicted_svm = svm_model.predict(feat_test)
svm_accuracy = accuracy_score(label_test, predicted_svm)
svm_fscore = f1_score(label_test, predicted_svm, average='micro') 

print(svm_accuracy)
print(svm_fscore)
# Out:
# 0.8653979238754326
# 0.8653979238754326

# %%
import eli5
from eli5.sklearn import PermutationImportance

perm = PermutationImportance(svm_model, random_state=1).fit(feat_test, label_test)
eli5.show_weights(perm, feature_names = feat_test.columns.tolist())
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.3025
#
#                     &plusmn; 0.0064
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 attitude
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 89.07%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1276
#
#                     &plusmn; 0.0074
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 appearance_animal
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.40%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0164
#
#                     &plusmn; 0.0028
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 appearance_object
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.57%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0149
#
#                     &plusmn; 0.0019
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 pubertal_development
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.56%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0013
#
#                     &plusmn; 0.0007
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 mother
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.70%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0008
#
#                     &plusmn; 0.0003
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 sexual_harrasment
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.74%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0006
#
#                     &plusmn; 0.0008
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 tag_num
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.83%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0003
#
#                     &plusmn; 0.0015
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 shame
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 100.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0
#
#                     &plusmn; 0.0000
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 gender_lgbt
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 100.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0
#
#                     &plusmn; 0.0000
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 gender_female
#             </td>
#         </tr>
#
#
#     </tbody>
# </table>

# %%
report_svm = classification_report(label_test, predicted_svm)
print(report_svm)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.85      0.90      1592
#            1       0.78      0.98      0.87      1105
#            2       0.70      0.31      0.42       180
#            3       0.00      0.00      0.00        13
#
#     accuracy                           0.87      2890
#    macro avg       0.61      0.54      0.55      2890
# weighted avg       0.87      0.87      0.86      2890
